# %%
import json
import xml.etree.ElementTree as ET
import re

import datetime
import logging
import traceback
import time

import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
def new_record():
    publication = {}
    publication["wos"] = {
        "title": "",
        "abstract": "",
        "source": "",
        "conference_id": "",
        "conference": "",
        "sortdate": "",
        "fund_ack": "",
        "keywords": "",
        "doi": "",
        "issn": "",
        "eissn": "",
        "art_no": "",
        "meeting_abs": "",
        "xref_doi": "",
        'wos_id': "",
        "parent_book_doi": "",
    }
    
    publication["scopus"] = {
        "dc:title": "",
        "prism:publicationName": "",
        "prism:coverDate": "",
        "prism:doi": "",
        "prism:issn": "",
        "prism:eIssn": "",
        "subtypeDescription": "",
        "openaccess": "",
        "openaccessFlag": "",
        "citedby-count": "",
        "dc:identifier": ""
    }
    
    publication["msa"] = {
        "title": "",
        "journal": "",
        "publisher": "",
        "doi": "",
        "abstract": "",
    }    
    
    return publication

# %%
def parse_raw_scopus(filename):
    parsed_records = []
    no_doi_in_record = 0
    count = 0

    with open(filename) as f:
        data = json.load(f)

        for record in data:
            publication = new_record()
            
            if 'dc:title' in record:
                publication["scopus"]['dc:title'] = record['dc:title']
                
            if 'prism:publicationName' in record:
                publication["scopus"]['prism:publicationName'] = record['prism:publicationName']
                
            if 'prism:coverDate' in record:
                publication["scopus"]['prism:coverDate'] = record['prism:coverDate']
            
            if 'subtypeDescription' in record:
                publication["scopus"]['subtypeDescription'] = record['subtypeDescription']
            
            if 'prism:doi' in record:
                publication["scopus"]['prism:doi'] = record['prism:doi']
            else:
                no_doi_in_record += 1
                
            if 'prism:eIssn' in record:
                publication["scopus"]['prism:eIssn'] = record['prism:eIssn']
                
            if 'prism:issn' in record:
                publication["scopus"]['prism:issn'] = record['prism:issn']
            
            
            if 'openaccess' in record:
                publication["scopus"]['openaccess'] = record['openaccess']
            
            if 'openaccessFlag' in record:
                publication["scopus"]['openaccessFlag'] = record['openaccessFlag']
            
            if 'citedby-count' in record:
                publication["scopus"]['citedby-count'] = record['citedby-count']
            
            if 'dc:identifier' in record:
                publication["scopus"]['dc:identifier'] = record['dc:identifier']
                
            parsed_records.append(publication)

    logging.info(f'Parsed Scopus results: {str(len(parsed_records))} records, with: {str(no_doi_in_record)} missing DOIs')
    return parsed_records, no_doi_in_record

# %%
filename = "/Users/277594b/Documents/repos/COKI-gcloud/testScopus.json"
records, no_doi_in_record = parse_raw_scopus(filename)

# %%
print(records[5])
# Out:
# {'wos': {'title': '', 'abstract': '', 'source': '', 'conference_id': '', 'conference': '', 'sortdate': '', 'fund_ack': '', 'keywords': '', 'doi': '', 'issn': '', 'eissn': '', 'art_no': '', 'meeting_abs': '', 'xref_doi': '', 'parent_book_doi': ''}, 'scopus': {'dc:title': 'Study of concrete damage mechanism under hydrostatic pressure by numerical simulations', 'prism:publicationName': 'Construction and Building Materials', 'prism:coverDate': '2018-01-30', 'prism:doi': '10.1016/j.conbuildmat.2017.11.083', 'prism:issn': '09500618', 'prism:eIssn': '', 'subtypeDescription': 'Article', 'openaccess': '0', 'openaccessFlag': False, 'citedby-count': '3', 'dc:identifier': 'SCOPUS_ID:85034780012'}}

# %%
def parse_raw_wos(filename):
    parsed_records = []
    no_doi_in_record = 0

    with open(filename) as f:
        tree = ET.fromstring("<root>" + f.read() + "</root>")
        for child in tree:
            for record in child:
                publication = new_record()
                not_found_doi = True
                
                publication["wos"]["wos_id"] = record[0].text
                
                for child in record[1]:
                    
                    for nested_child in child:
                        #print(nested_child.tag, nested_child.attrib)
                        
                        if(nested_child.tag =="{http://scientific.thomsonreuters.com/schema/wok5.4/public/FullRecord}titles"):
                            for title_type in nested_child:
                                if title_type.attrib["type"] == "item":
                                    publication["wos"]["title"] = title_type.text
                                if title_type.attrib["type"] == "source":
                                    publication["wos"]["source"] = title_type.text
                        
                        if(nested_child.tag == "{http://scientific.thomsonreuters.com/schema/wok5.4/public/FullRecord}pub_info"):
                            publication["wos"]["sortdate"] = nested_child.attrib["sortdate"] if "sortdate" in nested_child.attrib else ""
                            
                        if(nested_child.tag == "{http://scientific.thomsonreuters.com/schema/wok5.4/public/FullRecord}conferences"):
                            publication["wos"]["conference_id"] = nested_child[0].attrib['conf_id']
                            publication["wos"]["conference"] = nested_child[0][0][0].text
                            
                        if(nested_child.tag == "{http://scientific.thomsonreuters.com/schema/wok5.4/public/FullRecord}fund_ack"):
                            publication["wos"]["fund_ack"] = nested_child[0][0].text
                        
                        if(nested_child.tag == "{http://scientific.thomsonreuters.com/schema/wok5.4/public/FullRecord}abstracts"):
                            publication["wos"]["abstract"] = nested_child[0][0][0].text
                            
                        if(nested_child.tag == "{http://scientific.thomsonreuters.com/schema/wok5.4/public/FullRecord}keywords"):
                            publication["wos"]["keywords"] = []
                            for keyword in nested_child:
                                publication["wos"]["keywords"].append(keyword.text)
                    
                for identifier in list(record[2][1][0]):
                    if identifier.get('type') == "doi":
                        publication["wos"]["doi"] = identifier.get('value')
                        not_found_doi = False
                    elif identifier.get('type') == "issn":
                        publication["wos"]["issn"] = identifier.get('value')
                    elif identifier.get('type') == "eissn":
                        publication["wos"]["eissn"] = identifier.get('value')
                    elif identifier.get('type') == "art_no":
                        publication["wos"]["art_no"] = identifier.get('value')
                    elif identifier.get('type') == "meeting_abs":
                        publication["wos"]["meeting_abs"] = identifier.get('value')
                    elif identifier.get('type') == "xref_doi":
                        publication["wos"]["xref_doi"] = identifier.get('value')
                    elif identifier.get('type') == "parent_book_doi":
                        publication["wos"]["parent_book_doi"] = identifier.get('value')
                    else:
                        print("#####",identifier.get('type'))
                if not_found_doi:
                    no_doi_in_record += 1
                    
                parsed_records.append(publication)

    #logging.info(f'Parsed WOS results: {str(len(parsed_records))} records, with: {str(no_doi_in_record)} missing DOIs')
    return parsed_records, no_doi_in_record

# %%
filename = "/Users/277594b/Documents/repos/COKI-gcloud/testWOS.xml"
records, no_doi_in_record = parse_raw_wos(filename)

# %%
print(len(records))
#print(records)

for record in records:
    if record['wos']["doi"] == "":
        #print(record)
        if "xref_doi" in record['wos']: 
            print("xref", record['wos']['xref_doi'])
        elif "meeting_abs" in record['wos']: 
            print("meeting", record['wos']['meeting_abs'], record['wos']['conference'])
        elif "issn" in record['wos']: 
            print("issn", record['wos']['issn'])
        else:
            print("nope")
# Out:
# 716
# xref
# xref
# xref 10.1093/ahr/120.3.1118
# xref 10.1093/ahr/120.3.1103
# xref
# xref 10.1145/2814710.2814720
# xref 10.5749/futuante.12.1.0017
# xref
# xref 10.2118/172996-PA
# xref
# xref
# xref
# xref
# xref
# xref
# xref 10.1093/ahr/120.3.1118
# xref 10.1093/ahr/120.3.1103
# xref
# xref 10.1145/2814710.2814720
# xref 10.5749/futuante.12.1.0017
# xref
# xref 10.2118/172996-PA
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref 10.17310/ntj.2015.2.06
# xref
# xref 10.1109/MCOM.2015.7120013
# xref
# xref
# xref 10.1118/1.4926076
# xref
# xref
# xref
# xref 10.1038/ncb3181
# xref
# xref
# xref
# xref 10.1353/plo.2015.0135
# xref
# xref
# xref
# xref
# xref 10.1118/1.4926077
# xref
# xref
# xref
# xref
# xref 10.1126/science.348.6240.1216-c
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref
# xref 10.1145/2814710.2814713
# xref 10.1675/063.038.0201
# xref
# xref
# xref
# xref

# %%
def parse_raw_msa(filename):
    parsed_records = []
    no_doi_in_record = 0
    no_E_in_record = 0

    with open(filename) as f:
        data = json.load(f)
        line = 1
        for record_str in data:
            try:
                record = json.loads(str(record_str['E']))
                publication = new_record()
                
                if 'DOI' in record:
                    publication['msa']['doi'] = record['DOI']
                else:
                    no_doi_in_record += 1
                    
                if 'DN' in record:
                    publication['msa']['title'] = record['DN']
                    
                if 'BV' in record:
                    publication['msa']['journal'] = record['BV']
                    
                if 'PB' in record:
                    publication['msa']['publisher'] = record['PB']
                    
                if 'IA' in record:
                    if 'InvertedIndex' in record['IA']:
                        publication['msa']['abstract'] = " ".join(list(record['IA']['InvertedIndex'].keys()))
       
                parsed_records.append(publication)
            except:
                logging.warning(f'{line}, {record_str}')
                no_E_in_record += 1
            line = line + 1

    if no_E_in_record > 10:
        raise Exception

    logging.info(f'Parsed MSA results: {str(len(parsed_records))} records, with: {str(no_doi_in_record)} missing DOIs')
    return parsed_records, no_doi_in_record

# %%
filename = "/Users/277594b/Documents/repos/COKI-gcloud/testMSA.json"
parse_raw_msa(filename)
# Out:
# ([{'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The State of US Health, 1990-2016: Burden of Diseases, Injuries, and Risk Factors Among US States.',
#     'journal': 'JAMA',
#     'publisher': 'American Medical Association',
#     'doi': '10.1001/jama.2018.0158',
#     'abstract': 'Introduction Several studies have measured health outcomes in the United States, but none provided a comprehensive assessment of patterns by state. Objective To use results Global Burden Disease Study (GBD) to report trends burden diseases, injuries, and risk factors at state level from 1990 2016. Design Setting A systematic analysis published available data sources estimates disease age, sex, geography, year. Main Outcomes Measures Prevalence, incidence, mortality, life expectancy, healthy expectancy (HALE), years lost (YLLs) due premature lived with disability (YLDs), disability-adjusted life-years (DALYs) for 333 causes 84 95% uncertainty intervals (UIs) were computed. Results Between 2016, overall death rates States declined 745.2 (95% UI, 740.6 749.8) per 100\u202f000 persons 578.0 569.4 587.1) persons. The probability among adults aged 20 55 31 states Washington, DC In Hawaii had highest birth (81.3 years) Mississippi lowest (74.7 years), 6.6-year difference. Minnesota HALE (70.3 West Virginia (63.8 6.5-year leading DALYs 2016 ischemic heart lung cancer, while third cause was low back pain, chronic obstructive pulmonary disease. Opioid disorders moved 11th 7th representing 74.5% 42.8% 93.9%) change. each following 6 risks individually accounted more than 5% risk-attributable DALYs: tobacco consumption, high body mass index (BMI), poor diet, alcohol drug use, fasting plasma glucose, blood pressure. Across all US states, top terms attributable 1 3 causes: consumption (32 states), BMI (10 or (8 states). Conclusions Relevance There are wide differences level. Specific diseases factors, such as disorders, BMI, glucose level, increasing warrant increased attention. These can be used inform national priorities research, clinical care, policy.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Spatial and temporal patterns of mass bleaching of corals in the Anthropocene',
#     'journal': 'Science',
#     'publisher': 'AMER ASSOC ADVANCEMENT SCIENCE',
#     'doi': '10.1126/science.aan8048',
#     'abstract': 'Tropical reef systems are transitioning to a new era in which the interval between recurrent bouts of coral bleaching is too short for full recovery mature assemblages. We analyzed records at 100 globally distributed locations from 1980 2016. The median return time pairs severe events has diminished steadily since and now only 6 years. As global warming progressed, tropical sea surface temperatures warmer during current La Nina conditions than they were El Nino three decades ago. Consequently, as we transition Anthropocene, occurring more frequently all Nino–Southern Oscillation phases, increasing likelihood annual coming decades.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'A transcriptome-wide association study of 229,000 women identifies new candidate susceptibility genes for breast cancer',
#     'journal': 'Nature Genetics',
#     'publisher': 'Nat Genet',
#     'doi': '10.1038/s41588-018-0132-x',
#     'abstract': 'The breast cancer risk variants identified in genome-wide association studies explain only a small fraction of the familial relative risk, and genes responsible for these associations remain largely unknown. To identify novel loci likely causal genes, we performed transcriptome-wide study evaluating genetically predicted gene expression with 122,977 cases 105,974 controls European ancestry. We used data from Genotype-Tissue Expression Project to establish genetic models predict tissue evaluated model performance using Cancer Genome Atlas. Of 8,597 evaluated, significant were 48 at Bonferroni-corrected threshold P\u2009<\u20095.82\u2009×\u200910−6, including 14 not yet reported cancer. silenced 13 showed an effect 11 on cell proliferation and/or colony-forming efficiency. Our provides new insights into genetics biology.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Global Mortality From Firearms, 1990-2016',
#     'journal': 'JAMA',
#     'publisher': 'American Medical Association',
#     'doi': '10.1001/jama.2018.10060',
#     'abstract': 'Importance Understanding global variation in firearm mortality rates could guide prevention policies and interventions. Objective To estimate due to injury deaths from 1990 2016 195 countries territories. Design, Setting, Participants This study used deidentified aggregated data including 13\u202f812 location-years of vital registration generate estimates levels death by age-sex-year-location. The proportion suicides which a was the lethal means combined with an per capita gun ownership revised proxy measure evaluate relationship between availability or access firearms deaths. Exposures Firearm access. Main Outcomes Measures Cause-specific age, sex, location, year. Results Worldwide, it estimated that 251\u202f000 (95% uncertainty interval [UI], 195\u202f000-276\u202f000) people died injuries 2016, 6 (Brazil, United States, Mexico, Colombia, Venezuela, Guatemala) accounting for 50.5% UI, 42.2%-54.8%) those In 1990, there were 209\u202f000 172\u202f000 235\u202f000) injuries. Globally, majority homicides (64.0% [95% 54.2%-68.0%]; absolute value, 161\u202f000 107\u202f000-182\u202f000]); additionally, 27% suicide (67\u202f500 55\u202f400-84\u202f100]) 9% unintentional (23\u202f000 18\u202f200-24\u202f800]). From no significant decrease age-standardized homicide rate (−0.2% −0.8% 0.2%]). decreased globally at annualized 1.6% 1.1-2.0), but 124 territories included this study, these either constant increases estimated. There 0.9% 0.5%-1.3%) 2016. Aggregate highest among persons aged 20 24 years (for men, 34\u202f700 24\u202f900-39\u202f700] women, 3580 2810-4210]). Estimates number country associated higher ( P R2 \u2009=\u20090.21) \u2009=\u20090.35). Conclusions Relevance 195\u202f000 276\u202f000 homicides. Despite overall since across demographic subgroups.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The SUrvey for Pulsars and Extragalactic Radio Bursts – II. New FRB discoveries and their follow-up',
#     'journal': 'Monthly Notices of the Royal Astronomical Society',
#     'publisher': 'OXFORD UNIV PRESS UNITED KINGDOM',
#     'doi': '10.1093/mnras/stx3074',
#     'abstract': 'We report the discovery of four Fast Radio Bursts (FRBs) in ongoing SUrvey for Pulsars and Extragalactic at Parkes Telescope: FRBs 150610, 151206, 151230 160102. Our real-time discoveries have enabled us to conduct extensive, rapid multimessenger follow-up 12 major facilities sensitive radio, optical, X-ray, gamma-ray photons neutrinos on time-scales ranging from an hour a few months post-burst. No counterparts were found we provide upper limits afterglow luminosities. None seen repeat. Formal fits all show hints scattering while their intrinsic widths are unresolved time. FRB 151206 is low Galactic latitude, shows sharp spectral cut-off, 160102 has highest dispersion measure (DM = 2596.1 ± 0.3\u2009pc\u2009cm−3) detected date. Three high measures > 1500\u2009pc\u2009cm−3), favouring scenario where DM dominated by contributions intergalactic medium. The slope source counts distribution with fluences >2\u2009Jy\u2009ms \r\nα=−2.2+0.6−1.2\r\n still consistent Euclidean (α −3/2). also find that all-sky rate \r\n1.7+1.5−0.9×103\r\n \r\nFRBs/(4π sr)/day above \r\n∼2Jyms\r\n there currently no strong evidence latitude-dependent sky rate.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Discerning suicide in drug intoxication deaths: paucity and primacy of suicide notes and psychiatric history',
#     'journal': 'PLOS ONE',
#     'publisher': 'Public Library of Science',
#     'doi': '10.1371/journal.pone.0190200',
#     'abstract': 'Objective \r\nA paucity of corroborative psychological and psychiatric evidence may be inhibiting detection drug intoxication suicides in the United States. We evaluated relative importance suicide notes history classification by versus firearm (gunshot wound) plus hanging/suffocation—the other two major, but overtly violent methods.\r\n\r\n\r\nMethods \r\nThis observational multilevel (individual/county), multivariable study employed a generalized linear mixed model (GLMM) to analyze pooled undetermined intent deaths, as possible suicides, among population aged 15 years older 17 states participating National Violent Death Reporting System throughout 2011–2013. The outcome measure was odds classification, adjusted for demographics, precipitating circumstances, investigation characteristics.\r\n\r\n\r\nResults note, prior attempt, or affective disorder documented less than one-third one-quarter deaths. prevalence gaps were larger cases gunshot/hanging cases. latter more likely classified manner death (adjusted ratio [OR], 41.14; 95% CI, 34.43–49.15), documenting note (OR, 33.90; 26.11–44.05), attempt 2.42; 2.11–2.77), depression 1.61; 1.38 1.88), bipolar 1.41; 1.10–1.81). Stratification mechanism/cause intensified association between 45.43; 31.06–66.58). Prior 2.64; 2.19–3.18) 1.48; 1.17–1.87) associated with not cases.\r\n\r\n\r\nConclusions \r\nWithout psychological/psychiatric contributing US is profoundly under-reported. Findings harbor adverse implications surveillance, etiologic understanding, prevention'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The dispersion-brightness relation for fast radio bursts from a wide-field survey.',
#     'journal': 'Nature',
#     'publisher': 'Nature Publishing Group',
#     'doi': '10.1038/s41586-018-0588-y',
#     'abstract': 'Despite considerable efforts over the past decade, only 34 fast radio bursts—intense bursts of emission from beyond our Galaxy—have been reported1,2. Attempts to understand population as a whole have hindered by highly heterogeneous nature searches, which conducted with telescopes different sensitivities, at range frequencies, and in environments corrupted levels radio-frequency interference human activity. Searches further complicated uncertain burst positions brightnesses—a consequence transient sources poor angular resolution detecting instruments. The discovery repeating one source3, its subsequent localization4 dwarf galaxy distance 3.7 billion light years, confirmed that is located cosmological distances. However, remains elusive. Here we report well controlled, wide-field survey for these bursts. We found 20, none repeated during follow-up observations between 185–1,097\xa0hours after initial detections. sample includes both nearest most energetic detected so far. demonstrates there relationship dispersion\xa0and brightness that\xa0the high-fluence are nearby analogues more distant events higher-sensitivity, narrower-field surveys5.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Evidence for extremely rapid magma ocean crystallization and crust formation on Mars',
#     'journal': 'Nature',
#     'publisher': 'Nature Publishing Group',
#     'doi': '10.1038/s41586-018-0222-z',
#     'abstract': 'The formation of a primordial crust is critical step in the evolution terrestrial planets but timing this process poorly understood. mineral zircon powerful tool for constraining because it can be accurately dated with uranium-to-lead (U–Pb) isotopic decay system and resistant to subsequent alteration. Moreover, given high concentration hafnium zircon, lutetium-to-hafnium (176Lu–176Hf) used determine nature timescale its source reservoir1–3. Ancient igneous zircons crystallization ages around 4,430 million years (Myr) have been reported Martian meteorites that are believed represent regolith breccias from southern highlands Mars4,5. These present evolved lithologies interpreted reflect re-melted primary crust\n 4\n , thereby potentially providing insight into early crustal on Mars. Here, we report concomitant high-precision U–Pb Hf-isotope compositions ancient NWA\xa07034 breccia. Seven mostly concordant define 207Pb/206Pb dates ranging 4,476.3\xa0±\xa00.9 Myr ago 4,429.7\xa0±\xa01.0 ago, including oldest directly material All record unradiogenic initial inherited an enriched, andesitic-like extracted primitive mantle no later than 4,547 ago. Thus, existed Mars by time survived 100 before was reworked, possibly impacts4,5, produce magmas which crystallized. Given stable end product planetary differentiation, our data require accretion, core magma ocean were completed less 20 after Solar System. timescales support models suggest extremely rapid leading gravitationally unstable stratified mantle, subsequently overturns, resulting decompression melting rising cumulates production basaltic andesitic crust6,7.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'WHO World Mental Health Surveys International College Student Project: Prevalence and distribution of mental disorders.',
#     'journal': 'Journal of Abnormal Psychology',
#     'publisher': 'American Psychological Association',
#     'doi': '10.1037/abn0000362',
#     'abstract': ''}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The jet/wind outflow in Centaurus A: a local laboratory for AGN feedback',
#     'journal': 'Monthly Notices of the Royal Astronomical Society',
#     'publisher': 'Oxford University Press',
#     'doi': '10.1093/mnras/stx2890',
#     'abstract': 'We present new radio and optical images of the nearest galaxy Centaurus A its host NGC 5128. focus our investigation on northern transition region, where energy is transported from ~5 kpc (~5 arcmin) scales Northern Inner Lobe (NIL) to ~30 (~30 Middle (NML). Our Murchison Widefield Array observations at 154 MHz Parkes telescope 2.3 GHz show diffuse emission connecting NIL NML, in agreement with previous Australia Telescope Compact 1.4 GHz. Comparison these data widefield line relationship between NML ionised filaments that extend north NIL, reveal a filament east, possibly associated galactic wind. deep clear evidence for bipolar outflow central extending intermediate scales, despite non-detection southern counterpart NML. Thus, observational overview reveals number features proposed be AGN feedback mechanisms, often cited as likely have significant effects evolution models. As one closest galaxies us, therefore provides unique laboratory examine mechanisms detail.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Suicidal Thoughts and Behaviors Among First-Year College Students: Results From the WMH-ICS Project',
#     'journal': 'Journal of the American Academy of Child and Adolescent Psychiatry',
#     'publisher': 'Elsevier',
#     'doi': '10.1016/j.jaac.2018.01.018',
#     'abstract': 'Objective: College entrance may be a strategically well-placed “point of capture” for detecting late adolescents with suicidal thoughts and behaviors (STB). However, clear epidemiological picture STB among incoming college students is lacking. We present the first cross-national data on prevalence as well socio-demographic college-related correlates first-year students. Method: Web-based self-report surveys were obtained from 13,984 (response rate 45.5%) across 19 colleges in 8 countries (Australia, Belgium, Germany, Mexico, Northern Ireland, South Africa, Spain, United States). Results: Lifetime ideation, plans, attempts was 32.7%, 17.5%, 4.3%, respectively. The 12-month 17.2%, 8.8%, 1.0%, About three-fourths cases had onset before age 16 years (Q3 = 15.8), persistence figures range 41% to 53%. one-half (53.4%) lifetime ideators transitioned suicide plan; 22.1% planners an attempt. Attempts without plan less frequent (3.1%). Significant cross-nationally consistent generally modest effect size (median adjusted odds ratio [aOR] 1.7). Nonheterosexual orientation (aOR 3.3−7.9) heterosexual some same-sex attraction 1.9−2.3) strongest STB, transitioning ideation plans and/or 1.6−6.1). Conclusion: distribution widespread, relatively independent risk profile. Multivariate algorithms based high number factors are indicated efficiently link high-risk status effective preventive interventions.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Jets, Arcs and Shocks: NGC 5195 at radio wavelengths',
#     'journal': 'Monthly Notices of the Royal Astronomical Society',
#     'publisher': 'Oxford University Press',
#     'doi': '10.1093/mnras/sty390',
#     'abstract': 'We studied the nearby, interacting galaxy NGC 5195 (M 51b) in radio, optical and X-ray bands. mapped extended, low-surface-brightness features of its radio-continuum emission; determined energy content complex structure shock-ionized gas; constrained current activity level supermassive nuclear black hole. In particular, we combined data from European Very Long Baseline Interferometry Network (∼1-pc scale), our new e-MERLIN observations (∼10-pc Large Array (∼100–1000-pc to obtain a global picture injection this galaxy. put an upper limit luminosity (undetected) flat-spectrum radio core. find steep-spectrum, extended emission within 10 pc position, consistent with optically-thin synchrotron star formation or outflow powered by active galactic nucleus (AGN). A linear spur juts out source towards kpc-scale arcs (detected Hα bands). From size, shock velocity, Balmer line bubble, estimate that it was inflated long-term-average mechanical power ∼3–6 × 1041 erg s−1 over last 3–6 Myr. This is order magnitude more than can be provided formation, accretion argue jet-inflated bubble scenario associated previous episodes AGN most likely explanation for structures.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Response to Comment on “Precipitation drives global variation in natural selection”',
#     'journal': 'Science',
#     'publisher': 'American Association for The Advancement of Science, Washington, USA',
#     'doi': '10.1126/science.aan5760',
#     'abstract': 'The comment by Myers-Smith and Myers focuses on three main points: (i) the lack of a mechanistic explanation for climate-selection relationships, (ii) appropriateness climate data used in our analysis, (iii) focus estimating relationships across (rather than within) taxonomic groups. We address these critiques response.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The DSM-5 nonsuicidal self-injury disorder among incoming college students : Prevalence and associations with 12-month mental disorders and suicidal thoughts and behaviors',
#     'journal': 'Depression and Anxiety',
#     'publisher': '',
#     'doi': '10.1002/da.22754',
#     'abstract': 'Background: Approximately one in five college students report a history of nonsuicidal self-injury. However, it is unclear how many meet criteria for the recently proposed DSM-5 self-injury disorder (NSSI-D). In this study, we used full NSSI-D to identify those most need clinical care. Methods: Using data from Leuven College Surveys (n\xa0=\xa04,565), examined 12-month prevalence DSM-5\xa0NSSI-D large and representative sample incoming students. We also explored optimal frequency threshold as function interference functioning due NSSI, comorbidity patterns with other mental disorders (i.e., major depressive disorder, broad mania, generalized anxiety panic alcohol dependence) suicidal thoughts behaviors (STB). Results: Twelve-month was 0.8% more common among females (1.1%) than males (0.4%). The 5+ diagnostic confirmed yielding highest discrimination between subthreshold cases terms distress or disability NSSI. A dose–response relationship observed NSSI recency–severity NSSI-D, past no NSSI) number STB. occurred without comorbid individuals, remained associated severe role impairment when controlling disorders. Conclusions: These findings offer preliminary evidence that uncommon students, but may help improve deployment targeted resource allocation services. More work examining validity required.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Severe role impairment associated with mental disorders: Results of the WHO World Mental Health Surveys International College Student Project',
#     'journal': 'Depression and Anxiety',
#     'publisher': '',
#     'doi': '10.1002/da.22778',
#     'abstract': ''}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The associations between non-suicidal self-injury and first onset suicidal thoughts and behaviors',
#     'journal': 'Journal of Affective Disorders',
#     'publisher': 'Elsevier',
#     'doi': '10.1016/j.jad.2018.06.033',
#     'abstract': 'Abstract Background Theoretical and empirical literature suggests that non-suicidal self-injury (NSSI) is an important correlate of suicide risk. The present study was designed to evaluate: (a) whether NSSI associated with increased odds subsequent onsets suicidal thoughts behaviors (STB) independent common mental disorders, (b) risk transitioning from ideation attempt, (c) which characteristics are STB after NSSI. Method Using discrete-time survival models, based on retrospective age onset reports college students ( n \u202f=\u202f6,393, 56.8% female), we examined associations temporally prior (i.e., ideation, plan, attempt) controlling disorders MDD, Broad Mania, GAD, Panic Disorder, for Alcohol Dependence). were using logistic regressions. Results (OR\xa0=\xa02.8), plan (OR\xa0=\xa03.0), attempt (OR\xa0=\xa05.5) in models controlled the distribution disorders. Further analyses revealed a among those as well (ORs\xa0=\xa01.7–2.1). Several (e.g., automatic positive reinforcement, earlier NSSI) experiencing STB. Limitations Surveys relied self-report, thus, there potential recall bias. Conclusions This provides support conceptualization factor Investigation underlying pathways accounting these time-ordered avenue future research.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Rapid recovery of life at ground zero of the end-Cretaceous mass extinction',
#     'journal': 'Nature',
#     'publisher': 'Nature Publishing Group',
#     'doi': '10.1038/s41586-018-0163-6',
#     'abstract': 'The Cretaceous/Palaeogene mass extinction eradicated 76% of species on Earth1,2. It was caused by the impact an asteroid3,4 Yucatan carbonate platform in southern Gulf Mexico 66 million years ago\n 5\n , forming Chicxulub crater6,7. After extinction, recovery global marine ecosystem—measured as primary productivity—was geographically heterogeneous\n 8\n ; export production and North Atlantic–western Tethys slower than most other regions8–11, taking 300 thousand (kyr) to return levels similar those Late Cretaceous period. Delayed productivity closer crater implies impact-related environmental control, such toxic metal poisoning\n 12\n times. If no geographic pattern exists, best explanation for observed heterogeneity is a combination ecological factors—trophic interactions\n 13\n incumbency competitive exclusion opportunists\n 14\n —and ‘chance’8,15,16. question whether post-impact delayed has bearing predictability future patterns anthropogenically perturbed ecosystems. there relationship between distance from productivity, we would expect rates be slowest itself. Here present record foraminifera, calcareous nannoplankton, trace fossils elemental abundance data within crater, dated approximately first 200 kyr Palaeocene. We show that life reappeared basin just after high-productivity ecosystem established 30 kyr, which indicates proximity did not delay therefore control recovery. Ecological processes probably controlled are likely important response ocean rapid events.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Identification of nine new susceptibility loci for endometrial cancer',
#     'journal': 'Nature Communications',
#     'publisher': 'Nature Publishing Group',
#     'doi': '10.1038/s41467-018-05427-7',
#     'abstract': 'Endometrial cancer is the most commonly diagnosed of female reproductive tract in developed countries. Through genome-wide association studies (GWAS), we have previously identified eight risk loci for endometrial cancer. Here, present an expanded meta-analysis 12,906 cases and 108,979 controls (including new genotype data 5624 cases) identify nine novel significant loci, including a locus on 12q24.12 by meta-GWAS colorectal At five expression quantitative trait (eQTL) analyses candidate causal genes; alleles at two these associate with decreased genes, which encode negative regulators oncogenic signal transduction proteins (SH2B3 (12q24.12) NF1 (17q11.2)). In summary, this study has doubled number known revealed genes future study.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Developing a tablet computer-based application (‘App’) to measure self-reported alcohol consumption in Indigenous Australians',
#     'journal': 'BMC Medical Informatics and Decision Making',
#     'publisher': 'BioMed Central',
#     'doi': '10.1186/s12911-018-0583-0',
#     'abstract': 'Background\r\nThe challenges of assessing alcohol consumption can be greater in Indigenous communities where there may culturally distinct approaches to communication, sharing drinking containers and episodic patterns drinking. This paper discusses the processes used develop a tablet computer-based application (‘App’) collect detailed assessment Australians. The key features resulting App are described.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Whole-Genome Sequencing of African Dogs Provides Insights into Adaptations against Tropical Parasites',
#     'journal': 'Molecular Biology and Evolution',
#     'publisher': 'Oxford University Press',
#     'doi': '10.1093/molbev/msx258',
#     'abstract': ''}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Method overtness, forensic autopsy, and the evidentiary suicide note: A multilevel National Violent Death Reporting System analysis',
#     'journal': 'PLOS ONE',
#     'publisher': 'Public Library of Science',
#     'doi': '10.1371/journal.pone.0197805',
#     'abstract': 'Objective Higher prevalence of suicide notes could signify more conservatism in accounting and greater proneness to undercounting by method. We tested two hypotheses: (1) an evidentiary note is likely accompany suicides drug-intoxication other poisoning, as less violent forensically overt methods, than firearm hanging/suffocation; (2) performance a forensic autopsy attenuates any observed association between overtness method the reported presence note. Methods This multilevel (individual/county), multivariable analysis employed generalized linear mixed model (GLMM). Representing 17 states participating United States National Violent Death Reporting System throughout 2011–2013, study population comprised registered suicides, aged 15 years older. Decedents totaled 32,151. The outcome measure was relative odds authenticated Results An documented 31% cases. Inspection full showed manifest among drug intoxication (adjusted ratio [OR], 1.70; 95% CI, 1.56, 1.85) poisoning (OR, 2.12; 1.85, 2.42) referent. Respective excesses were larger when there no or status unknown 1.86; 1.61, 2.14) 2.25; 1.86, 2.72) comparisons with 1.62, 1.45, 1.82 OR, 2.01; 1.66, 2.43). Hanging/suffocation did not differ from referent given autopsy. Conclusions Suicide requires substantial affirmative evidence establish manner death, affirmation appears demand especially high burden proof. Findings their implications argue for stringent investigative standards, better training, resources support comprehensive accurate case ascertainment, foundation developing evidence-based prevention initiatives.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'An evolving jet from a strongly magnetized accreting X-ray pulsar',
#     'journal': 'Nature',
#     'publisher': 'Nature Publishing Group',
#     'doi': '10.1038/s41586-018-0524-1',
#     'abstract': 'Relativistic jets are observed throughout the Universe and strongly affect their surrounding environments on a range of physical scales, from Galactic binary systems1 to galaxies clusters galaxies2. All types accreting black hole neutron star have been launch jets3, with exception stars strong magnetic fields4,5 (higher than 1012 gauss), leading conclusion that field strength inhibits jet formation6. However, radio emission recently detected two such objects could origin, among other possible explanations7,8, indicating this long-standing idea might need be reconsidered. But definitive observational evidence is still lacking. Here we report observations an evolving launched by magnetized above theoretical maximum rate given Eddington limit. The luminosity orders magnitude fainter those seen in similar X-ray luminosities9, implying important role for properties\xa0of regulating power. Our result also shows fields ultra-luminous pulsars do not prevent sources launching jets.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The High Time Resolution Universe Pulsar Survey – XIII. PSR J1757−1854, the most accelerated binary pulsar',
#     'journal': 'Monthly Notices of the Royal Astronomical Society',
#     'publisher': 'Oxford University Press',
#     'doi': '10.1093/mnrasl/sly003',
#     'abstract': 'We report the discovery of PSR J1757$-$1854, a 21.5-ms pulsar in highly-eccentric, 4.4-h orbit around neutron star (NS) companion. J1757$-$1854 exhibits some most extreme relativistic parameters any known pulsar, including strongest effects due to gravitational-wave (GW) damping, with merger time 76 Myr. Following 1.6-yr timing campaign, we have measured five post-Keplerian (PK) parameters, yielding two component masses ($m_\\text{p}=1.3384(9)\\,\\text{M}_\\odot$ and $m_\\text{c}=1.3946(9)\\,\\text{M}_\\odot$) plus three tests general relativity (GR), which theory passes. The larger mass NS companion provides important clues regarding binary formation J1757$-$1854. With simulations suggesting 3-$\\sigma$ measurements both contribution Lense-Thirring precession rate change semi-major axis deformation within $\\sim7-9$ years, stands out as unique laboratory for new gravitational theories.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The City of the Future',
#     'journal': 'Urban Planning',
#     'publisher': '',
#     'doi': '10.17645/up.v3i2.1247',
#     'abstract': 'Limiting global warming to 1.5 °C will require rapid decarbonisation of the world’s electricity and transport systems. This must occur against a background continuing urbanisation shift information economy. While replacement fossil fuels in generation is underway, urban currently dominated by petrol diesel-powered vehicles. The City Future need be built around different paradigm. article argues that new model polycentric city linked fast electric rail, with local access based on autonomous “community”-owned cars buses supplemented bicycles, bikes scooters, all generated from renewables. Less space wasted roads parking, enabling higher accessibility yet more usable public open space. Building cities future national governments accelerate initiatives through appropriate policy settings strategic investment. precise way which individual move into vary, illustrates how transformation could work for Australian cities, like Sydney, some most car dependent world, using financial partnerships.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Will growth in cryptomarket drug buying increase the harms of illicit drugs',
#     'journal': 'Addiction',
#     'publisher': 'Wiley',
#     'doi': '10.1111/add.13899',
#     'abstract': "Background and aim\r\nCryptomarkets—on-line, anonymous market-places for illicit goods services that specialize mainly in drugs—account a small but rapidly growing share of the drug market many countries. Policy responses so far are based generally on assumption their rise will only increase harms. In this contribution debate, we question assumption.\r\n\r\nMethods\r\nWe provide narrative review emerging literature connected to cryptomarkets. We use MacCoun & Reuter's formula understand effect population-level increases total harm as depending level associated with each unit use. then consider potential cryptomarkets or decrease harms benefits related use, specific attention quality drugs sold non-drug-related customers.\r\n\r\nResults\r\nIt is likely both amount range substances sold. However, argue effects depend upon whether also safety products sold, harm-reducing information consumers reduce transactional conflict involved purchasing.\r\n\r\nConclusions\r\nThere an evidence base macro micro users. Future researchers should appropriately matched comparative designs establish more firmly differential sourcing on- off-line. While it unlikely on-line trade can be eradicated completely, respond regulation enforcement ways have complex, sometimes unanticipated, benefits."}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The Murchison Widefield Array Transients Survey (MWATS). A search for low frequency variability in a bright Southern hemisphere sample',
#     'journal': 'Monthly Notices of the Royal Astronomical Society',
#     'publisher': '',
#     'doi': '10.1093/mnras/sty2801',
# ...
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Factors influencing non-participation in an exercise program and attitudes towards physical activity amongst cancer survivors',
#     'journal': 'Supportive Care in Cancer',
#     'publisher': 'Springer',
#     'doi': '10.1007/s00520-017-3952-9',
#     'abstract': 'Purpose\r\nThe purposes of this study are to investigate factors influencing non-participation in a structured exercise program for cancer survivors and explore survivors’ experiences attitudes relation physical activity participation.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Mechanisms of Modulation of Calcium Phosphate Pathological Mineralization by Mobile and Immobile Small-Molecule Inhibitors',
#     'journal': 'Journal of Physical Chemistry B',
#     'publisher': 'American Chemical Society',
#     'doi': '10.1021/acs.jpcb.7b10956',
#     'abstract': 'Potential pathways for inhibiting crystal growth are via either disrupting local microenvironments surrounding crystal–solution interfaces or physically blocking solute molecule attachment. However, the actual mode of inhibition may be more complicated due to characteristic time scale inhibitor adsorption and relaxation a well-bound state at surfaces. Here we demonstrate role citrate (CA) hydroxycitrate (HCA) in brushite (DCPD, CaHPO4·2H2O) crystallization over broad range both concentrations supersaturations by situ atomic force microscopy (AFM). We observed that inhibitors exhibit two distinct actions: control surface decrease step density high [1̅00]Cc velocity concentration low supersaturation. The switching modes depends on terrace lifetime, slow kinetics along direction provides specific site...'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Lupin seed γ-conglutin: Extraction and purification methods - A review',
#     'journal': 'Trends in Food Science and Technology',
#     'publisher': 'Elsevier',
#     'doi': '10.1016/j.tifs.2017.12.008',
#     'abstract': 'Abstract Background Lupin, the largest legume crop in Australia, is gaining global attention because of its unique protein γ-conglutin, which has shown promise as a nutraceutical for controlling blood glucose level and thus reducing risk type II diabetes development. Type chronic condition affecting millions individuals worldwide, urgently requires natural side effect free therapies alternatives to currently used drugs. Purification γ-conglutin opens up new avenue high-value products from lupin seeds nutraceuticals, market predicted reach US$ 250 billion by 2018 ( Dutta, Mahabir, & Pathak, 2013 ). Scope approach Previously, several research groups have reported trials on extracting purifying proteins seed. However, most these methods focussed isolates food ingredients. Very few reports aimed purify total proteins, but are time-consuming unsuitable commercial scale production high purity due involvement many processing steps application. Hence there need fully understand all extraction purification processes terms their advantages limitations, so that an effective scalable process grade may be designed future. Key findings conclusions This article reviews provide basis development novel technique/process this potentially highly valuable protein.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Evaporation of a suspended binary mixture droplet in a heated flowing gas stream',
#     'journal': 'Experimental Thermal and Fluid Science',
#     'publisher': 'Elsevier',
#     'doi': '10.1016/j.expthermflusci.2017.10.025',
#     'abstract': 'Abstract Studying vaporization of binary mixture liquid droplets as a model system provides useful information for understanding several engineering applications involving multicomponent systems. The present study investigated behaviour both polar and non-polar droplet systems in hot convective environment using mathematical experiments. A lumped parameter rapid mixing evaporation accounting non-ideal solution temperature dependent physical properties was presented. predicted temporal variation diameter were validated against the experimental data heptane-decane water-glycerol mixture. Experiments involved size measurement millimetre-size at constant gas ∼353\u202fK free stream velocity ∼4.3\u202fm/s. In general, predictions good agreement with experiments however some deviations prediction noted transition stage specifically which attributed to phase diffusional resistance not accounted modelling framework. Inclusion activity coefficient into shown have insignificant effect on rate Internal motions induced by external shear flow internal density difference quantified. Time scales based heat transfer (convective thermal diffusion) mass diffusion motion estimated. It that unsteady heating duration fall within two limits set time scales.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Deterministic Conversion of Uncertain Manpower Planning Optimization Problem',
#     'journal': 'IEEE Transactions on Fuzzy Systems',
#     'publisher': '',
#     'doi': '10.1109/tfuzz.2018.2803736',
#     'abstract': 'Manpower planning is a very important component of human resource management. However, there are many indeterminate factors that should be taken into consideration in manpower planning. For example, the decision employees to quit job determined by their preference, which beyond control department. It can realistically modeled as random variable when historical data quitting rate large enough. Otherwise, it only regarded an uncertain inadequate. In this paper, we discuss optimization problem for manufacturing company with hierarchical system, where variable. First, formulate mathematical model problem, influence on production outputs consideration. Second, present deterministic conversion method transform equivalent discrete-time problem. further converted linear programming equality constraint and inequality constraint. Finally, use real from Singapore, Denmark, China carry out numerical simulation make comparison results obtained based stochastic show advantages our method.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Spectral approximation properties of isogeometric analysis with variable continuity',
#     'journal': 'Computer Methods in Applied Mechanics and Engineering',
#     'publisher': 'North-Holland',
#     'doi': '10.1016/j.cma.2018.01.042',
#     'abstract': 'Abstract We study the spectral approximation properties of isogeometric analysis with local continuity reduction basis. Such results in a decrement interconnection between degrees freedom mesh, which allows for large computational savings during solution resulting linear system. The extra that modify method. convergence rate such refined is equivalent to maximum show how breaks and inhomogeneity basis lead artifacts frequency spectra, as stopping bands outliers, present unified description these effects finite element method, analysis, analysis. Accuracy approximations can be improved by using non-standard quadrature rules. In particular, optimal rules reductions eigenvalue errors yield two orders convergence, it occurs standard'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Dispersion-minimized mass for isogeometric analysis',
#     'journal': 'Computer Methods in Applied Mechanics and Engineering',
#     'publisher': 'North-Holland',
#     'doi': '10.1016/j.cma.2018.06.016',
#     'abstract': 'Abstract We introduce the dispersion-minimized mass for isogeometric analysis to approximate structural vibration, which we model as a second-order differential eigenvalue problem. The reduces error significantly, from optimum order of 2 p superconvergence + th elements with maximum continuity, in return leads more accurate method. first establish dispersion error, where leading term is explicitly written terms stiffness and entries, arbitrary polynomial elements. derive one dimension by solving -dimensional local matrix problem approximation then extend it multiple dimensions on tensor-product grids. show that can also be obtained approximating using optimally-blended quadratures. generalize lower quadrature-blending results approximations well quadrature rules. Various numerical examples validate eigenfunction estimates.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'Prediction of solar irradiance using ray-tracing techniques for coral macro- and micro-habitats',
#     'journal': 'Marine Environmental Research',
#     'publisher': 'Elsevier',
#     'doi': '10.1016/j.marenvres.2018.08.004',
#     'abstract': 'Abstract Light distribution on coral reefs is very heterogeneous at the microhabitat level and an important determinant of thermal microenvironments. This study implemented a solar load model that uses backward ray-tracing method to estimate macroscale microscale variations irradiance penetrating ocean surface impacting surfaces colonies. We then explored whether morphological characteristics such as tissue darkness (or pigmentation) thickness may influence amount light captured its spectral by two contrasting colony morphologies, branching massive. Results global horizontal above below sea-surface colonies were validated using spectrometer scans, field measurements, empirical correlations. The results horizontal, irradiated, shaded levels altitude angles for PAR, UVA UVB compared well with spectrometer-based observations (typically within 5%). In general, comparison between measurements indicated contributions clouds, turbidity, tides in various depth (up 5\u202fm) typically 5–10% each other. Moreover, effect or pigmentation microenvironment was notably more pronounced massive species than colony. provided insights thinner have ability intercept difference terms 0.1\u202fmm 0.8\u202fmm both approximately 2\u202fW\u202fm −2 , which quite unlikely overall heat budgets.'}},
#   {'wos': {'title': '',
#     'abstract': '',
#     'source': '',
#     'conference_id': '',
#     'conference': '',
#     'sortdate': '',
#     'fund_ack': '',
#     'keywords': '',
#     'doi': '',
#     'issn': '',
#     'eissn': '',
#     'art_no': '',
#     'meeting_abs': '',
#     'xref_doi': '',
#     'wos_id': '',
#     'parent_book_doi': ''},
#    'scopus': {'dc:title': '',
#     'prism:publicationName': '',
#     'prism:coverDate': '',
#     'prism:doi': '',
#     'prism:issn': '',
#     'prism:eIssn': '',
#     'subtypeDescription': '',
#     'openaccess': '',
#     'openaccessFlag': '',
#     'citedby-count': '',
#     'dc:identifier': ''},
#    'msa': {'title': 'The obstacles to cold chain implementation in developing countries: insights from Vietnam',
#     'journal': 'The International Journal of Logistics Management',
#     'publisher': '',
#     'doi': '10.1108/IJLM-02-2017-0026',
#     'abstract': 'Purpose\r\n\r\n\r\n\r\n\r\nThe purpose of this paper is to identify the obstacles that impede cold chain implementation in developing countries.\r\n\r\n\r\n\r\n\r\nDesign/methodology/approach\r\n\r\n\r\n\r\n\r\nA grounded theory methodology was employed execute research. Eight semi-structured, in-depth interviews were conducted with senior managers Vietnam. In addition, consistent guidelines, authors utilized archival data facilitate development.\r\n\r\n\r\n\r\n\r\nFindings\r\n\r\n\r\n\r\n\r\nThe results analysis revealed a total ten key obstacles: deficient professional skills, lack quality and safety-control measures, high concentration intermediaries, poor infrastructure, information systems, cost installation operation, inadequate education training at farmer level, deficiency standardization, government support for local businesses social norms.\r\n\r\n\r\n\r\n\r\nOriginality/value\r\n\r\n\r\n\r\n\r\nAlthough many have recognized enormity food wastage limited employment countries compared developed countries, few efforts been made explore reasons use chains countries. There are several noteworthy theoretical managerial contributions emerged from addressing gap.'}},
#   ...],
#  31)

# %%
filename = "/Users/277594b/Documents/repos/COKI-gcloud/testScopus.json"
parse_raw_scopus(filename)
# Out:
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'Curtin University'}],
#  'citedby-count': '0',
#  'dc:creator': 'Finn H.',
#  'dc:identifier': 'SCOPUS_ID:85049161920',
#  'dc:title': 'The defamatory potential of ad hominem criticism: Guidance for '
#              'advocacy in public forums',
#  'eid': '2-s2.0-85049161920',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85049161920',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85049161920?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85049161920&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85049161920&origin=inward',
#            '@ref': 'scopus-citedby'}],
#  'openaccess': '0',
#  'openaccessFlag': False,
#  'prism:aggregationType': 'Journal',
#  'prism:coverDate': '2018-01-31',
#  'prism:coverDisplayDate': '31 January 2018',
#  'prism:doi': '10.1071/PC17022',
#  'prism:eIssn': '22044604',
#  'prism:issn': '10382097',
#  'prism:pageRange': None,
#  'prism:publicationName': 'Pacific Conservation Biology',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85049161920',
#  'source-id': '19795',
#  'subtype': 'ip',
#  'subtypeDescription': 'Article in Press'}
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'Curtin University'}],
#  'citedby-count': '1',
#  'dc:creator': 'Lopez R.',
#  'dc:identifier': 'SCOPUS_ID:85045299344',
#  'dc:title': 'Comparison of dispute boards and statutory adjudication in '
#              'construction',
#  'eid': '2-s2.0-85045299344',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85045299344',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85045299344?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85045299344&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85045299344&origin=inward',
#            '@ref': 'scopus-citedby'}],
#  'openaccess': '0',
#  'openaccessFlag': False,
#  'prism:aggregationType': 'Journal',
#  'prism:coverDate': '2018-01-31',
#  'prism:coverDisplayDate': '31 January 2018',
#  'prism:doi': '10.1680/jmapl.17.00037',
#  'prism:eIssn': '17514312',
#  'prism:issn': '17514304',
#  'prism:issueIdentifier': '2',
#  'prism:pageRange': '70-78',
#  'prism:publicationName': 'Proceedings of Institution of Civil Engineers: '
#                           'Management, Procurement and Law',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85045299344',
#  'prism:volume': '171',
#  'source-id': '12100155428',
#  'subtype': 'ar',
#  'subtypeDescription': 'Article'}
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Beijing',
#                   'affiliation-country': 'China',
#                   'affilname': 'China University of Petroleum - Beijing'},
#                  {'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'Curtin University'}],
#  'citedby-count': '2',
#  'dc:creator': 'Jiang Q.',
#  'dc:identifier': 'SCOPUS_ID:85044677908',
#  'dc:title': 'Heat flow study of the Emeishan large igneous province region: '
#              'Implications for the geodynamics of the Emeishan mantle plume',
#  'eid': '2-s2.0-85044677908',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85044677908',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85044677908?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85044677908&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85044677908&origin=inward',
#            '@ref': 'scopus-citedby'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0040195117305309',
#            '@ref': 'full-text'}],
#  'openaccess': '0',
#  'openaccessFlag': False,
#  'pii': 'S0040195117305309',
#  'prism:aggregationType': 'Journal',
#  'prism:coverDate': '2018-01-31',
#  'prism:coverDisplayDate': '31 January 2018',
#  'prism:doi': '10.1016/j.tecto.2017.12.027',
#  'prism:issn': '00401951',
#  'prism:pageRange': '11-27',
#  'prism:publicationName': 'Tectonophysics',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85044677908',
#  'prism:volume': '724-725',
#  'source-id': '28990',
#  'subtype': 'ar',
#  'subtypeDescription': 'Article'}
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'Curtin University'},
#                  {'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'PIVET Medical Centre'}],
#  'article-number': '14',
#  'citedby-count': '1',
#  'dc:creator': 'Keane K.',
#  'dc:identifier': 'SCOPUS_ID:85041320317',
#  'dc:title': 'DHEA supplementation confers no additional benefit to that of '
#              'growth hormone on pregnancy and live birth rates in IVF patients '
#              'categorized as poor prognosis',
#  'eid': '2-s2.0-85041320317',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85041320317',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85041320317?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85041320317&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85041320317&origin=inward',
#            '@ref': 'scopus-citedby'}],
#  'openaccess': '1',
#  'openaccessFlag': True,
#  'prism:aggregationType': 'Journal',
#  'prism:coverDate': '2018-01-31',
#  'prism:coverDisplayDate': '31 January 2018',
#  'prism:doi': '10.3389/fendo.2018.00014',
#  'prism:eIssn': '16642392',
#  'prism:issueIdentifier': 'JAN',
#  'prism:pageRange': None,
#  'prism:publicationName': 'Frontiers in Endocrinology',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85041320317',
#  'prism:volume': '9',
#  'source-id': '21100229210',
#  'subtype': 'ar',
#  'subtypeDescription': 'Article'}
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'Curtin University'}],
#  'article-number': '012707',
#  'citedby-count': '0',
#  'dc:creator': 'Rawlins C.',
#  'dc:identifier': 'SCOPUS_ID:85041448114',
#  'dc:title': 'Two-center convergent close-coupling approach to '
#              'positron-helium-ion collisions',
#  'eid': '2-s2.0-85041448114',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85041448114',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85041448114?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85041448114&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85041448114&origin=inward',
#            '@ref': 'scopus-citedby'}],
#  'openaccess': '0',
#  'openaccessFlag': False,
#  'prism:aggregationType': 'Journal',
#  'prism:coverDate': '2018-01-30',
#  'prism:coverDisplayDate': '30 January 2018',
#  'prism:doi': '10.1103/PhysRevA.97.012707',
#  'prism:eIssn': '24699934',
#  'prism:issn': '24699926',
#  'prism:issueIdentifier': '1',
#  'prism:pageRange': None,
#  'prism:publicationName': 'Physical Review A',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85041448114',
#  'prism:volume': '97',
#  'source-id': '21100874237',
#  'subtype': 'ar',
#  'subtypeDescription': 'Article'}
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Tianjin',
#                   'affiliation-country': 'China',
#                   'affilname': 'Tianjin University'},
#                  {'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'Curtin University'}],
#  'citedby-count': '3',
#  'dc:creator': 'Cui J.',
#  'dc:identifier': 'SCOPUS_ID:85034780012',
#  'dc:title': 'Study of concrete damage mechanism under hydrostatic pressure by '
#              'numerical simulations',
#  'eid': '2-s2.0-85034780012',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85034780012',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85034780012?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85034780012&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85034780012&origin=inward',
#            '@ref': 'scopus-citedby'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0950061817322924',
#            '@ref': 'full-text'}],
#  'openaccess': '0',
#  'openaccessFlag': False,
#  'pii': 'S0950061817322924',
#  'prism:aggregationType': 'Journal',
#  'prism:coverDate': '2018-01-30',
#  'prism:coverDisplayDate': '30 January 2018',
#  'prism:doi': '10.1016/j.conbuildmat.2017.11.083',
#  'prism:issn': '09500618',
#  'prism:pageRange': '440-449',
#  'prism:publicationName': 'Construction and Building Materials',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85034780012',
#  'prism:volume': '160',
#  'source-id': '24443',
#  'subtype': 'ar',
#  'subtypeDescription': 'Article'}
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Bandung',
#                   'affiliation-country': 'Indonesia',
#                   'affilname': 'Institut Teknologi Bandung'},
#                  {'@_fa': 'true',
#                   'affiliation-city': 'Jakarta',
#                   'affiliation-country': 'Indonesia',
#                   'affilname': 'Lembaga Ilmu Pengetahuan Indonesia'}],
#  'article-number': '012003',
#  'citedby-count': '0',
#  'dc:creator': 'Mufakhir F.',
#  'dc:identifier': 'SCOPUS_ID:85042359040',
#  'dc:title': 'Leaching of silicon from ferronickel (FeNi) smelting slag with '
#              'sodium hydroxide solution at atmospheric pressure',
#  'eid': '2-s2.0-85042359040',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85042359040',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85042359040?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85042359040&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85042359040&origin=inward',
#            '@ref': 'scopus-citedby'}],
#  'openaccess': '1',
#  'openaccessFlag': True,
#  'prism:aggregationType': 'Conference Proceeding',
#  'prism:coverDate': '2018-01-30',
#  'prism:coverDisplayDate': '30 January 2018',
#  'prism:doi': '10.1088/1757-899X/285/1/012003',
#  'prism:eIssn': '1757899X',
#  'prism:issn': '17578981',
#  'prism:issueIdentifier': '1',
#  'prism:pageRange': None,
#  'prism:publicationName': 'IOP Conference Series: Materials Science and '
#                           'Engineering',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85042359040',
#  'prism:volume': '285',
#  'source-id': '19700200831',
#  'subtype': 'cp',
#  'subtypeDescription': 'Conference Paper'}
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'Curtin University'}],
#  'citedby-count': '0',
#  'dc:creator': 'Mohseni B.',
#  'dc:identifier': 'SCOPUS_ID:85046352360',
#  'dc:title': 'Online detection of partial discharge inside power transformer '
#              'winding through IFRA',
#  'eid': '2-s2.0-85046352360',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85046352360',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85046352360?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85046352360&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85046352360&origin=inward',
#            '@ref': 'scopus-citedby'}],
#  'openaccess': '0',
#  'openaccessFlag': False,
#  'prism:aggregationType': 'Conference Proceeding',
#  'prism:coverDate': '2018-01-29',
#  'prism:coverDisplayDate': '29 January 2018',
#  'prism:doi': '10.1109/PESGM.2017.8273725',
#  'prism:eIssn': '19449933',
#  'prism:isbn': '9781538622124',
#  'prism:issn': '19449925',
#  'prism:pageRange': '1-5',
#  'prism:publicationName': 'IEEE Power and Energy Society General Meeting',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85046352360',
#  'prism:volume': '2018-January',
#  'source-id': '20600195623',
#  'subtype': 'cp',
#  'subtypeDescription': 'Conference Paper'}
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'Curtin University'}],
#  'citedby-count': '0',
#  'dc:creator': 'Jabalameli N.',
#  'dc:identifier': 'SCOPUS_ID:85046370840',
#  'dc:title': 'Optimal online charging of plug-in electric vehicles considering '
#              'voltage unbalance factor',
#  'eid': '2-s2.0-85046370840',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85046370840',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85046370840?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85046370840&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85046370840&origin=inward',
#            '@ref': 'scopus-citedby'}],
#  'openaccess': '0',
#  'openaccessFlag': False,
#  'prism:aggregationType': 'Conference Proceeding',
#  'prism:coverDate': '2018-01-29',
#  'prism:coverDisplayDate': '29 January 2018',
#  'prism:doi': '10.1109/PESGM.2017.8274389',
#  'prism:eIssn': '19449933',
#  'prism:isbn': '9781538622124',
#  'prism:issn': '19449925',
#  'prism:pageRange': '1-5',
#  'prism:publicationName': 'IEEE Power and Energy Society General Meeting',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85046370840',
#  'prism:volume': '2018-January',
#  'source-id': '20600195623',
#  'subtype': 'cp',
#  'subtypeDescription': 'Conference Paper'}
# {'@_fa': 'true',
#  'affiliation': [{'@_fa': 'true',
#                   'affiliation-city': 'Perth',
#                   'affiliation-country': 'Australia',
#                   'affilname': 'Curtin University'}],
#  'citedby-count': '0',
#  'dc:creator': 'Datta A.',
#  'dc:identifier': 'SCOPUS_ID:85046352132',
#  'dc:title': 'Power sharing in a hybrid microgrid with bidirectional switch',
#  'eid': '2-s2.0-85046352132',
#  'link': [{'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85046352132',
#            '@ref': 'self'},
#           {'@_fa': 'true',
#            '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85046352132?field=author,affiliation',
#            '@ref': 'author-affiliation'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85046352132&origin=inward',
#            '@ref': 'scopus'},
#           {'@_fa': 'true',
#            '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85046352132&origin=inward',
#            '@ref': 'scopus-citedby'}],
#  'openaccess': '0',
#  'openaccessFlag': False,
#  'prism:aggregationType': 'Conference Proceeding',
#  'prism:coverDate': '2018-01-29',
#  'prism:coverDisplayDate': '29 January 2018',
#  'prism:doi': '10.1109/PESGM.2017.8274281',
#  'prism:eIssn': '19449933',
#  'prism:isbn': '9781538622124',
#  'prism:issn': '19449925',
#  'prism:pageRange': '1-5',
#  'prism:publicationName': 'IEEE Power and Energy Society General Meeting',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85046352132',
#  'prism:volume': '2018-January',
#  'source-id': '20600195623',
#  'subtype': 'cp',
#  'subtypeDescription': 'Conference Paper'}
# ([('10.1071/PC17022', ''),
#   ('10.1680/jmapl.17.00037', ''),
#   ('10.1016/j.tecto.2017.12.027', ''),
#   ('10.3389/fendo.2018.00014', ''),
#   ('10.1103/PhysRevA.97.012707', ''),
#   ('10.1016/j.conbuildmat.2017.11.083', ''),
#   ('10.1088/1757-899X/285/1/012003', ''),
#   ('10.1109/PESGM.2017.8273725', ''),
#   ('10.1109/PESGM.2017.8274389', ''),
#   ('10.1109/PESGM.2017.8274281', '')],
#  0)

# %%
filename = "/Users/277594b/Documents/repos/COKI-gcloud/testWOS.xml"
parse_raw_wos(filename)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-73323bc129a4> in <module>()
#       1 filename = "/Users/277594b/Documents/repos/COKI-gcloud/testWOS.xml"
# ----> 2 parse_raw_wos(filename)
#
# <ipython-input-54-ad9b978e8188> in parse_raw_wos(filename)
#       6         tree = ET.fromstring("<root>" + f.read() + "</root>")
#       7         for child in tree:
# ----> 8             print(child.tostring(elem, 'utf-8'))
#       9             break
#      10             for record in child:
#
# AttributeError: 'xml.etree.ElementTree.Element' object has no attribute 'tostring'
